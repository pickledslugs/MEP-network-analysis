# %%
import camelot

# %%
tables = camelot.read_pdf("pdf/26.05.05_oop_2023.pdf", pages='8-20')

# %%
tables
# Out:
# <TableList n=14>

# %%
for tabs in tables:
    print(tabs.df)
# Out:
#                                                    0  \
# 0  Категория об-\nщепрофессио-\nКод и наименовани...
# 1  Естественнона-\nучная и об-\nщеинженерная \nоб...
# 2
# 3                             Управление \nпроектами
# 4
# 5                               Управление \nрисками
#
#                                                    1  \
# 0
# 1  ОПК-2 Способен применять \nестественнонаучные ...
# 2  ОПК-3 Способен проводить \nизмерения и наблюде...
# 3  ОПК-4 Способен адаптировать-\nся к изменяющимс...
# 4  ОПК-5 Способен понимать \nпринципы работы совр...
# 5  ОПК-6 Способен идентифици-\nровать опасности, ...
#
#                                                    2
# 0
# 1  ОПК-2.1 Знает основные законы естественнонаучн...
# 2  ОПК-3.1 Знает способы измерений, записи и хран...
# 3  ОПК-4.1 Знает порядок установления целей проек...
# 4  ОПК-5.1 Знает принципы работы современных инфо...
# 5  ОПК-6.1 Знает общие принципы и алгоритмы оценк...
# ...
